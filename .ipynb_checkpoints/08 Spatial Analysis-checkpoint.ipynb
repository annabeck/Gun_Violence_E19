# %% [markdown]
# ## SPATIAL ANALYSIS

# %%
import os
import requests

import numpy as np
import pandas as pd
import seaborn as sns

import folium
import geopandas as gpd
import fiona
import shapely


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline
import zipfile
from zipfile import ZipFile
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## Download the Shape file of US Counties

# %%
folder_root = '/Users/Anna/Documents/GitHub/Gun_Violence_E19/maps/tl_2017_us_county'

os.chdir(folder_root) # change directions
zip_file = zipfile.ZipFile(os.path.join(folder_root,'tl_2017_us_county.shp.zip')) # open the zip file
zip_file.extractall()
zip_file.close()
county_data = gpd.read_file('tl_2017_us_county.shp') # read the un-zipped shape-file
os.remove(os.path.join(folder_root, 'tl_2017_us_county.shp')) # delete the un-zipped file again, as it is too big to for GitHub sharing

# %%
county_data['Statecode'] = pd.to_numeric(county_data['STATEFP'])
county_data = county_data[['Statecode','NAME', 'NAMELSAD','geometry']]

# %%
state_names = pd.read_csv('state-geocodes-v2016.csv', sep = ';')
state_names = state_names[['State (FIPS)','Name']]
state_names
# Out:
#     State (FIPS)                  Name
# 0              0      Northeast Region
# 1              0  New England Division
# 2              9           Connecticut
# 3             23                 Maine
# 4             25         Massachusetts
# ..           ...                   ...
# 59             2                Alaska
# 60             6            California
# 61            15                Hawaii
# 62            41                Oregon
# 63            53            Washington
#
# [64 rows x 2 columns]

# %%
geo_county = pd.merge(county_data,state_names,left_on=['Statecode'], right_on = ['State (FIPS)'], how = 'left')

# %%
geo_county = geo_county[geo_county['Name']!='Alaska']
geo_county = geo_county[geo_county['Name']!='Hawaii']
geo_county = geo_county[geo_county['Name']!='Districts of Columbia']
geo_county = geo_county.dropna()
geo_county['Name'].unique()
# Out:
# array(['Nebraska', 'Washington', 'New Mexico', 'South Dakota', 'Texas',
#        'California', 'Kentucky', 'Ohio', 'Alabama', 'Georgia',
#        'Wisconsin', 'Arkansas', 'Oregon', 'Pennsylvania', 'Mississippi',
#        'Missouri', 'Colorado', 'North Carolina', 'Utah', 'Oklahoma',
#        'Virginia', 'Tennessee', 'Wyoming', 'West Virginia', 'Louisiana',
#        'New York', 'Michigan', 'Indiana', 'Massachusetts', 'Kansas',
#        'Idaho', 'Florida', 'Nevada', 'Illinois', 'Vermont', 'Connecticut',
#        'Montana', 'New Jersey', 'Minnesota', 'North Dakota', 'Maryland',
#        'Iowa', 'South Carolina', 'Maine', 'New Hampshire', 'Arizona',
#        'Delaware', 'District of Columbia', 'Rhode Island'], dtype=object)

# %%
fig, ax = plt.subplots(figsize = (20,20))
geo_county.plot(ax = ax)

plt.xlim(right = -65)
plt.xlim(left = -127)
plt.ylim(bottom = 22.5)
# Out:
# (22.5, 50.6337605)

# %%
extreme = geo_county.bounds
min_x = extreme['minx'].min()
max_x = extreme['maxx'].max()
min_y = extreme['miny'].min()
max_y = extreme['maxy'].max()

# %%
horisontal_grid = np.arange(min_x,max_x,500)
vertical_grid = np.arange(min_y,max_y,500)

x = []
y = [] 

for h in horisontal_grid: 
    for v in vertical_grid: 
        x.append(h)
        y.append(v)

# %% [markdown]
# ## Spatial Analysis

# %%
os.chdir('/Users/Anna/Documents/GitHub/Gun_Violence_E19/Data')
df = pd.read_csv('final_dataset.csv.gz')

# %%
mass_shootings = df[df['Mass Shooting']== True]
non_shootings = df[df['Non-Shooting Incident']== True]
print(len(mass_shootings),len(non_shootings))
# Out:
# 1352 42134

# %%
X_ms = np.array(mass_shootings[['latitude','longitude']]) # extract the long-lat columns for KKN analysis
X_ns = np.array(non_shootings[['latitude','longitude']])
print(len(X_ms), len(X_ns))
type(X_ms)
type(X_ms[1])
X_ms
# Out:
# 1352 42134
# array([[ 36.8508, -76.2859],
#        [ 40.6775, -73.7629],
#        [ 32.3986, -91.1579],
#        ...,
#        [ 33.0758, -96.7106],
#        [ 39.9321, -75.1027],
#        [ 40.2164, -74.0187]])

# %%
X = np.vstack((X_ms[1],X_ns))
X
# Out:
# array([[  40.6775,  -73.7629],
#        [  30.6884,  -87.048 ],
#        [  42.6828,  -89.0187],
#        ...,
#        [  42.0925,  -72.5803],
#        [  40.6887,  -73.599 ],
#        [  47.6638, -117.235 ]])

# %%
nbrs = NearestNeighbors(n_neighbors=2, algorithm='auto', metric='haversine').fit(X) # Find the closest neightbor to each incident (2 because the first is itself)
distance, indices = nbrs.kneighbors(X,)

# %%
print(distance[0])
print(indices[0])
print(X[0],X[39401])
# Out:
# [0.         0.00881137]
# [    0 39401]
# [ 40.6775 -73.7629] [ 40.6692 -73.7659]

# %%
from haversine import haversine, Unit
a = (40.6775, -73.7629)
b =(40.6692, -73.7659)
haversine((40.6775, -73.7629),(40.6692, -73.7659))
# Out:
# 0.9569694858171143

# %%
0.02753808062626267/0.00023603
0.9569694858171143/0.00881137
# Out:
# 108.60620832142041

# %%
df_indices = pd.DataFrame(indices)
df_distances = pd.DataFrame(distances)

#Change column names
col_ind = []
for c in df_indices.columns:
    col = 'indc_'+str(c+1)
    col_ind.append(col)
df_indices.columns=col_ind

col_dis = []
for c in df_distances.columns:
    col = 'dist_'+str(c+1)
    col_dis.append(col)
df_distances.columns=col_dis

# %%
kkn = pd.concat([df_distances,df_indices], axis=1)
kkn[['State','County','Mass Shooting']] = pd.DataFrame(df[['State','county','Mass Shooting']], index = kkn.index)

# %%
kkn_ms = kkn[kkn['Mass Shooting']== True] # only mass-shootings

# %%
describe_dist = kkn_ms.groupby(['State','County']).describe().reset_index() # descriptive statistics on the KKN

# %%
disc_geo = describe_dist.iloc[:,0:2].join(describe_dist.iloc[:,10:14]).join(describe_dist.iloc[:,17]) #keep only descriptive stats for the dist_2 (The nearest neightbor that is not the point itself)
disc_geo
# Out:
#              State            County dist_2                                \
#                                       count      mean       std       min
# 0          Alabama    Calhoun County    1.0  0.007026       NaN  0.007026
# 1          Alabama     Elmore County    1.0  0.001747       NaN  0.001747
# 2          Alabama  Jefferson County    6.0  0.001090  0.000725  0.000216
# 3          Alabama        Lee County    1.0  0.003495       NaN  0.003495
# 4          Alabama    Madison County    3.0  0.000468  0.000810  0.000000
# ..             ...               ...    ...       ...       ...       ...
# 285     Washington     Yakima County    1.0  0.002736       NaN  0.002736
# 286  West Virginia    Kanawha County    1.0  0.001105       NaN  0.001105
# 287      Wisconsin  Winnebago County    1.0  0.013596       NaN  0.013596
# 288      Wisconsin   Marathon County    1.0  0.000756       NaN  0.000756
# 289      Wisconsin  Milwaukee County    7.0  0.000541  0.000500  0.000000
#
#
# ...

# %%
disc_geo.sort_values(('dist_2', 'count'), ascending=False).head(15)
# Out:
#             State               County dist_2                                \
#                                         count      mean       std       min
# 85       Illinois          Cook County  101.0  0.000601  0.001036  0.000000
# 19     California   Los Angeles County   31.0  0.001113  0.000841  0.000000
# 56        Florida    Miami-Dade County   28.0  0.000871  0.000864  0.000065
# 252     Tennessee        Shelby County   24.0  0.000986  0.000984  0.000000
# 138      Michigan         Wayne County   22.0  0.000832  0.000655  0.000000
# 263         Texas        Harris County   20.0  0.001670  0.001317  0.000000
# 120     Louisiana       Orleans Parish   18.0  0.000349  0.000474  0.000000
# 76        Georgia        Fulton County   17.0  0.001439  0.002012  0.000000
# 209          Ohio      Cuyahoga County   16.0  0.001906  0.002457  0.000000
# 45        Florida        Orange County   14.0  0.001469  0.001217  0.000000
# ...

# %% [markdown]
# ## Get Demographics for Couties and measure racial index

# %%
desc_county = df[['State', 'County','White_Pop', 'Black_AA_Pop',
       'AmericanIndian_AlasNative_Pop', 'Asian_Pop', 'PacificNative_Pop',
       'OtherRace_Pop', 'Social_Security', 'PerCapita_Income']]

desc_county[['White_Pop', 'Black_AA_Pop',
       'AmericanIndian_AlasNative_Pop', 'Asian_Pop', 'PacificNative_Pop',
       'OtherRace_Pop', 'Social_Security', 'PerCapita_Income']].apply(lambda x: pd.to_numeric(x))

desc_county=desc_county.groupby(['State', 'County']).mean()

desc_county['Total_Pop'] = desc_county[['White_Pop', 'Black_AA_Pop',
       'AmericanIndian_AlasNative_Pop', 'Asian_Pop', 'PacificNative_Pop',
       'OtherRace_Pop']].sum(axis=1)

races = ['White_Pop', 'Black_AA_Pop',
       'AmericanIndian_AlasNative_Pop', 'Asian_Pop', 'PacificNative_Pop',
       'OtherRace_Pop']
# Out:
# White_Pop
# Black_AA_Pop
# AmericanIndian_AlasNative_Pop
# Asian_Pop
# PacificNative_Pop
# OtherRace_Pop
#                                 White_Pop  Black_AA_Pop  \
# State     County
# Alabama   Baldwin County    178930.833333  20261.371795
#           Calhoun County     85161.300000  23908.500000
#           Cullman County     79136.000000    920.772727
#           DeKalb County      60859.069767   1131.720930
#           Elmore County      60618.930233  18080.069767
# ...                                   ...           ...
# Wisconsin Waukesha County   368180.443182   6358.437500
#           Winnebago County  156990.464789   3809.295775
#           Wood County        69340.630769    546.492308
# Wyoming   Laramie County     87651.148936   2549.000000
#           Natrona County     76438.095238   1428.440476
#
#                             AmericanIndian_AlasNative_Pop     Asian_Pop  \
# State     County
# Alabama   Baldwin County                      1766.166667   1337.628205
# ...
